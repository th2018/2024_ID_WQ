# %%
import pandas as pd # read data from a CSV
import matplotlib.pyplot as plt

import os

# %%
data = {
    "site"  :   [""],

    
"station_nm" : [""],
    "dec_lat_va": [0.0],
    "dec_long_va":  [0.0],
    'max_bias':  [0.0],
        "RMS":  [0.0],
        "correlation_coefficient": [0.0]
       }
result = pd.DataFrame(data)
print(result)
# Out:
#   site station_nm  dec_lat_va  dec_long_va  max_bias  RMS  \
# 0                         0.0          0.0       0.0  0.0
#
#    correlation_coefficient
# 0                      0.0

# %%
all_files = os.listdir( )
csv_files = [file for file in all_files if file.endswith(".csv")]
for csv in csv_files:
    df=pd.read_csv(csv)
    result=pd.concat([result,df])

print(result)
# Out:
#        site                                       station_nm  dec_lat_va  \
# 0                                                               0.000000
# 0  13296000           YANKEE FORK SALMON RIVER NR CLAYTON ID   44.278889
# 0  13139510           BIG WOOD RIVER AT HAILEY ID TOTAL FLOW   43.517222
# 0  13092747    ROCK CREEK AB HWY 30/93 XING AT TWIN FALLS ID   42.562500
# 0  13311450                      SUGAR CREEK NR STIBNITE, ID   44.936361
# 0  12322000                    KOOTENAI RIVER AT PORTHILL ID   48.996389
# 0  13340600  NF CLEARWATER RIVER NR CANYON RANGER STATION ID   46.840556
# 0  13341050                      CLEARWATER RIVER NR PECK ID   46.500278
# 0  13310800     EFSF SALMON R ABV MEADOW CRK NR STIBNITE, ID   44.902250
# 0  13311000            EF OF SF SALMON RIVER AT STIBNITE, ID   44.905722
# 0  13150430    SILVER CREEK AT SPORTSMAN ACCESS NR PICABO ID   43.323361
# 0  13317660  SNAKE RIVER AT McDUFF RAPIDS AT CHINA GARDEN ID   46.003056
#
#    dec_long_va  max_bias       RMS  correlation_coefficient  Unnamed: 0
# 0     0.000000  0.000000  0.000000                 0.000000         NaN
# 0  -114.733889  1.612987  1.160534                 0.957873         0.0
# 0  -114.321667  2.634097  1.268432                 0.874226         0.0
# 0  -114.494722  1.852796  0.662556                 0.861660         0.0
# 0  -115.337222  2.648836  0.867932                 0.954293         0.0
# 0  -116.507500  4.561600  1.425718                 0.860068         0.0
# 0  -115.621111  1.757390  1.007526                 0.976463         0.0
# 0  -116.392500  1.876998  1.494644                 0.557563         0.0
# 0  -115.325667  2.803433  0.724318                 0.939629         0.0
# 0  -115.329500  2.765273  0.824088                 0.941843         0.0
# 0  -114.108350  2.843270  1.014837                 0.851693         0.0
# 0  -116.916944  4.083411  1.097208                 0.957799         0.0

# %%
plt.hist(result['correlation_coefficient'])
plt.show()

plt.hist(result['RMS'])
plt.show()
