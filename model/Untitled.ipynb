# %%
import pandas as pd # read data from a CSV
import matplotlib.pyplot as plt

import os

# %%
data = {
    "site"  :   [""],

    
"station_nm" : [""],
    "dec_lat_va": [0.0],
    "dec_long_va":  [0.0],
    'max_bias':  [0.0],
        "RMS":  [0.0],
        "correlation_coefficient": [0.0]
       }
result = pd.DataFrame(data)
print(result)
# Out:
#   site station_nm  dec_lat_va  dec_long_va  max_bias  RMS  \
# 0                         0.0          0.0       0.0  0.0
#
#    correlation_coefficient
# 0                      0.0

# %%
all_files = os.listdir( )
csv_files = [file for file in all_files if file.endswith(".csv")]
for csv in csv_files:
    df=pd.read_csv(csv)
    result=pd.concat([result,df])

result=result[ result["dec_lat_va"] >0]
print(result)
# Out:
#        site                                       station_nm  dec_lat_va  \
# 0  13176400         EF OWYHEE RIVER AT CRUTCHER CROSSING, ID   42.261369
# 0  13296000           YANKEE FORK SALMON RIVER NR CLAYTON ID   44.278889
# 0  13139510           BIG WOOD RIVER AT HAILEY ID TOTAL FLOW   43.517222
# 0  13092747    ROCK CREEK AB HWY 30/93 XING AT TWIN FALLS ID   42.562500
# 0  13311450                      SUGAR CREEK NR STIBNITE, ID   44.936361
# 0  12398600     PEND OREILLE RIVER AT INTERNATIONAL BOUNDARY   48.998814
# 0  12322000                    KOOTENAI RIVER AT PORTHILL ID   48.996389
# 0  13340600  NF CLEARWATER RIVER NR CANYON RANGER STATION ID   46.840556
# 0  13341050                      CLEARWATER RIVER NR PECK ID   46.500278
# 0  13310800     EFSF SALMON R ABV MEADOW CRK NR STIBNITE, ID   44.902250
# 0  13190500          SF BOISE RIVER AT ANDERSON RANCH DAM ID   43.343611
# 0  13311000            EF OF SF SALMON RIVER AT STIBNITE, ID   44.905722
# 0  13018300                     CACHE CREEK NEAR JACKSON, WY   43.452153
# 0  13150430    SILVER CREEK AT SPORTSMAN ACCESS NR PICABO ID   43.323361
# 0  13211205                      BOISE RIVER AT CALDWELL, ID   43.677353
# 0  13317660  SNAKE RIVER AT McDUFF RAPIDS AT CHINA GARDEN ID   46.003056
# 0  12413370     EF PINE CREEK ABV NABOB CR NEAR PINEHURST ID   47.476667
#
#    dec_long_va  max_bias       RMS  correlation_coefficient  Unnamed: 0  \
# 0  -116.868442  3.785012  1.119745                 0.899881         0.0
# 0  -114.733889  1.764651  1.160616                 0.957855         0.0
# 0  -114.321667  2.634097  1.268432                 0.874226         0.0
# 0  -114.494722  1.918446  0.662609                 0.861675         0.0
# 0  -115.337222  2.648836  0.867932                 0.954293         0.0
# 0  -117.353579  4.648062  1.568888                 0.940344         0.0
# 0  -116.507500  4.558921  1.425980                 0.860028         0.0
# 0  -115.621111  1.757390  1.007526                 0.976463         0.0
# 0  -116.392500  1.876998  1.494644                 0.557563         0.0
# 0  -115.325667  2.803433  0.724318                 0.939629         0.0
# 0  -115.477500  2.455272  1.822477                 0.130351         0.0
# 0  -115.329500  2.765273  0.824088                 0.941843         0.0
# 0  -110.704091  1.891353  0.542036                 0.929548         0.0
# 0  -114.108350  2.840332  1.014827                 0.851699         0.0
# 0  -116.701131  2.605681  0.983914                 0.945638         0.0
# 0  -116.916944  4.083411  1.097208                 0.957799         0.0
# 0  -116.221667  2.918060  1.105336                 0.938397         0.0
#
#     alt_va  drain_area_va                       perm
# 0  4253.65         2140.0          tmean..degrees.C.
# 0  5950.00          189.0                      log_Q
# 0      NaN            NaN                        NaN
# 0  3630.00          259.0          tmean..degrees.C.
# 0      NaN            NaN                        NaN
# 0  1700.00        25200.0                      log_Q
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0  6750.00           10.6  tmean..degrees.C. & log_Q
# 0  4834.45           70.0          tmean..degrees.C.
# 0      NaN         3363.0                      log_Q
# 0      NaN            NaN                        NaN
# 0  2490.00           28.2                      log_Q

# %%
CALDWELL, ID elevation: 2,375′ft
# Out:
#   Cell In[4], line 1
#     CALDWELL, ID elevation: 2,375′ft
#                                 ^
# SyntaxError: invalid decimal literal

# %%
print(result.iloc[0, 0])
print(result.iloc[1, 0])
print(result.iloc[1, 1])
# Out:
# 13176400
# 13296000
# YANKEE FORK SALMON RIVER NR CLAYTON ID

# %%
plt.hist(result['correlation_coefficient'])
plt.show()

plt.hist(result['RMS'])
plt.show()

# %%
# 13190500: only one year of bad training data

# %%
correlation_coefficient = result.sort_values(by='correlation_coefficient')
correlation_coefficient
# Out:
#        site                                       station_nm  dec_lat_va  \
# 0  13190500          SF BOISE RIVER AT ANDERSON RANCH DAM ID   43.343611
# 0  13341050                      CLEARWATER RIVER NR PECK ID   46.500278
# 0  13150430    SILVER CREEK AT SPORTSMAN ACCESS NR PICABO ID   43.323361
# 0  12322000                    KOOTENAI RIVER AT PORTHILL ID   48.996389
# 0  13092747    ROCK CREEK AB HWY 30/93 XING AT TWIN FALLS ID   42.562500
# 0  13139510           BIG WOOD RIVER AT HAILEY ID TOTAL FLOW   43.517222
# 0  13176400         EF OWYHEE RIVER AT CRUTCHER CROSSING, ID   42.261369
# 0  13018300                     CACHE CREEK NEAR JACKSON, WY   43.452153
# 0  12413370     EF PINE CREEK ABV NABOB CR NEAR PINEHURST ID   47.476667
# 0  13310800     EFSF SALMON R ABV MEADOW CRK NR STIBNITE, ID   44.902250
# 0  12398600     PEND OREILLE RIVER AT INTERNATIONAL BOUNDARY   48.998814
# 0  13311000            EF OF SF SALMON RIVER AT STIBNITE, ID   44.905722
# 0  13211205                      BOISE RIVER AT CALDWELL, ID   43.677353
# 0  13311450                      SUGAR CREEK NR STIBNITE, ID   44.936361
# 0  13317660  SNAKE RIVER AT McDUFF RAPIDS AT CHINA GARDEN ID   46.003056
# 0  13296000           YANKEE FORK SALMON RIVER NR CLAYTON ID   44.278889
# 0  13340600  NF CLEARWATER RIVER NR CANYON RANGER STATION ID   46.840556
#
#    dec_long_va  max_bias       RMS  correlation_coefficient  Unnamed: 0  \
# 0  -115.477500  2.455272  1.822477                 0.130351         0.0
# 0  -116.392500  1.876998  1.494644                 0.557563         0.0
# 0  -114.108350  2.840332  1.014827                 0.851699         0.0
# 0  -116.507500  4.558921  1.425980                 0.860028         0.0
# 0  -114.494722  1.918446  0.662609                 0.861675         0.0
# 0  -114.321667  2.634097  1.268432                 0.874226         0.0
# 0  -116.868442  3.785012  1.119745                 0.899881         0.0
# 0  -110.704091  1.891353  0.542036                 0.929548         0.0
# 0  -116.221667  2.918060  1.105336                 0.938397         0.0
# 0  -115.325667  2.803433  0.724318                 0.939629         0.0
# 0  -117.353579  4.648062  1.568888                 0.940344         0.0
# 0  -115.329500  2.765273  0.824088                 0.941843         0.0
# 0  -116.701131  2.605681  0.983914                 0.945638         0.0
# 0  -115.337222  2.648836  0.867932                 0.954293         0.0
# 0  -116.916944  4.083411  1.097208                 0.957799         0.0
# 0  -114.733889  1.764651  1.160616                 0.957855         0.0
# 0  -115.621111  1.757390  1.007526                 0.976463         0.0
#
#     alt_va  drain_area_va                       perm
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0  4834.45           70.0          tmean..degrees.C.
# 0      NaN            NaN                        NaN
# 0  3630.00          259.0          tmean..degrees.C.
# 0      NaN            NaN                        NaN
# 0  4253.65         2140.0          tmean..degrees.C.
# 0  6750.00           10.6  tmean..degrees.C. & log_Q
# 0  2490.00           28.2                      log_Q
# 0      NaN            NaN                        NaN
# 0  1700.00        25200.0                      log_Q
# 0      NaN            NaN                        NaN
# 0      NaN         3363.0                      log_Q
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0  5950.00          189.0                      log_Q
# 0      NaN            NaN                        NaN

# %%
RMS = result.sort_values(by='RMS')
RMS
# Out:
#        site                                       station_nm  dec_lat_va  \
# 0  13018300                     CACHE CREEK NEAR JACKSON, WY   43.452153
# 0  13092747    ROCK CREEK AB HWY 30/93 XING AT TWIN FALLS ID   42.562500
# 0  13310800     EFSF SALMON R ABV MEADOW CRK NR STIBNITE, ID   44.902250
# 0  13311000            EF OF SF SALMON RIVER AT STIBNITE, ID   44.905722
# 0  13311450                      SUGAR CREEK NR STIBNITE, ID   44.936361
# 0  13211205                      BOISE RIVER AT CALDWELL, ID   43.677353
# 0  13340600  NF CLEARWATER RIVER NR CANYON RANGER STATION ID   46.840556
# 0  13150430    SILVER CREEK AT SPORTSMAN ACCESS NR PICABO ID   43.323361
# 0  13317660  SNAKE RIVER AT McDUFF RAPIDS AT CHINA GARDEN ID   46.003056
# 0  12413370     EF PINE CREEK ABV NABOB CR NEAR PINEHURST ID   47.476667
# 0  13176400         EF OWYHEE RIVER AT CRUTCHER CROSSING, ID   42.261369
# 0  13296000           YANKEE FORK SALMON RIVER NR CLAYTON ID   44.278889
# 0  13139510           BIG WOOD RIVER AT HAILEY ID TOTAL FLOW   43.517222
# 0  12322000                    KOOTENAI RIVER AT PORTHILL ID   48.996389
# 0  13341050                      CLEARWATER RIVER NR PECK ID   46.500278
# 0  12398600     PEND OREILLE RIVER AT INTERNATIONAL BOUNDARY   48.998814
# 0  13190500          SF BOISE RIVER AT ANDERSON RANCH DAM ID   43.343611
#
#    dec_long_va  max_bias       RMS  correlation_coefficient  Unnamed: 0  \
# 0  -110.704091  1.891353  0.542036                 0.929548         0.0
# 0  -114.494722  1.918446  0.662609                 0.861675         0.0
# 0  -115.325667  2.803433  0.724318                 0.939629         0.0
# 0  -115.329500  2.765273  0.824088                 0.941843         0.0
# 0  -115.337222  2.648836  0.867932                 0.954293         0.0
# 0  -116.701131  2.605681  0.983914                 0.945638         0.0
# 0  -115.621111  1.757390  1.007526                 0.976463         0.0
# 0  -114.108350  2.840332  1.014827                 0.851699         0.0
# 0  -116.916944  4.083411  1.097208                 0.957799         0.0
# 0  -116.221667  2.918060  1.105336                 0.938397         0.0
# 0  -116.868442  3.785012  1.119745                 0.899881         0.0
# 0  -114.733889  1.764651  1.160616                 0.957855         0.0
# 0  -114.321667  2.634097  1.268432                 0.874226         0.0
# 0  -116.507500  4.558921  1.425980                 0.860028         0.0
# 0  -116.392500  1.876998  1.494644                 0.557563         0.0
# 0  -117.353579  4.648062  1.568888                 0.940344         0.0
# 0  -115.477500  2.455272  1.822477                 0.130351         0.0
#
#     alt_va  drain_area_va                       perm
# 0  6750.00           10.6  tmean..degrees.C. & log_Q
# 0  3630.00          259.0          tmean..degrees.C.
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0      NaN         3363.0                      log_Q
# 0      NaN            NaN                        NaN
# 0  4834.45           70.0          tmean..degrees.C.
# 0      NaN            NaN                        NaN
# 0  2490.00           28.2                      log_Q
# 0  4253.65         2140.0          tmean..degrees.C.
# 0  5950.00          189.0                      log_Q
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0  1700.00        25200.0                      log_Q
# 0      NaN            NaN                        NaN

# %%
max_bias = result.sort_values(by='max_bias')
max_bias
# Out:
#        site                                       station_nm  dec_lat_va  \
# 0  13340600  NF CLEARWATER RIVER NR CANYON RANGER STATION ID   46.840556
# 0  13296000           YANKEE FORK SALMON RIVER NR CLAYTON ID   44.278889
# 0  13341050                      CLEARWATER RIVER NR PECK ID   46.500278
# 0  13018300                     CACHE CREEK NEAR JACKSON, WY   43.452153
# 0  13092747    ROCK CREEK AB HWY 30/93 XING AT TWIN FALLS ID   42.562500
# 0  13190500          SF BOISE RIVER AT ANDERSON RANCH DAM ID   43.343611
# 0  13211205                      BOISE RIVER AT CALDWELL, ID   43.677353
# 0  13139510           BIG WOOD RIVER AT HAILEY ID TOTAL FLOW   43.517222
# 0  13311450                      SUGAR CREEK NR STIBNITE, ID   44.936361
# 0  13311000            EF OF SF SALMON RIVER AT STIBNITE, ID   44.905722
# 0  13310800     EFSF SALMON R ABV MEADOW CRK NR STIBNITE, ID   44.902250
# 0  13150430    SILVER CREEK AT SPORTSMAN ACCESS NR PICABO ID   43.323361
# 0  12413370     EF PINE CREEK ABV NABOB CR NEAR PINEHURST ID   47.476667
# 0  13176400         EF OWYHEE RIVER AT CRUTCHER CROSSING, ID   42.261369
# 0  13317660  SNAKE RIVER AT McDUFF RAPIDS AT CHINA GARDEN ID   46.003056
# 0  12322000                    KOOTENAI RIVER AT PORTHILL ID   48.996389
# 0  12398600     PEND OREILLE RIVER AT INTERNATIONAL BOUNDARY   48.998814
#
#    dec_long_va  max_bias       RMS  correlation_coefficient  Unnamed: 0  \
# 0  -115.621111  1.757390  1.007526                 0.976463         0.0
# 0  -114.733889  1.764651  1.160616                 0.957855         0.0
# 0  -116.392500  1.876998  1.494644                 0.557563         0.0
# 0  -110.704091  1.891353  0.542036                 0.929548         0.0
# 0  -114.494722  1.918446  0.662609                 0.861675         0.0
# 0  -115.477500  2.455272  1.822477                 0.130351         0.0
# 0  -116.701131  2.605681  0.983914                 0.945638         0.0
# 0  -114.321667  2.634097  1.268432                 0.874226         0.0
# 0  -115.337222  2.648836  0.867932                 0.954293         0.0
# 0  -115.329500  2.765273  0.824088                 0.941843         0.0
# 0  -115.325667  2.803433  0.724318                 0.939629         0.0
# 0  -114.108350  2.840332  1.014827                 0.851699         0.0
# 0  -116.221667  2.918060  1.105336                 0.938397         0.0
# 0  -116.868442  3.785012  1.119745                 0.899881         0.0
# 0  -116.916944  4.083411  1.097208                 0.957799         0.0
# 0  -116.507500  4.558921  1.425980                 0.860028         0.0
# 0  -117.353579  4.648062  1.568888                 0.940344         0.0
#
#     alt_va  drain_area_va                       perm
# 0      NaN            NaN                        NaN
# 0  5950.00          189.0                      log_Q
# 0      NaN            NaN                        NaN
# 0  6750.00           10.6  tmean..degrees.C. & log_Q
# 0  3630.00          259.0          tmean..degrees.C.
# 0      NaN            NaN                        NaN
# 0      NaN         3363.0                      log_Q
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0  4834.45           70.0          tmean..degrees.C.
# 0  2490.00           28.2                      log_Q
# 0  4253.65         2140.0          tmean..degrees.C.
# 0      NaN            NaN                        NaN
# 0      NaN            NaN                        NaN
# 0  1700.00        25200.0                      log_Q
